# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datanormal=pd.read_csv('finalized.csv')
datak=pd.read_csv('new_data.csv')
datal=pd.read_csv('new_data_1.csv')
datat=pd.read_csv('new_dara_2.csv')

# %%
datal.isna().sum()
# Out:
# ID                       0
# Gender                   0
# Male                     0
# Female                   0
# Years_in_US              0
# Maritial_Status          0
# People_Family            0
# People_Household         0
# Family_income         9813
# Household_Income         0
# GlycoHemoglobin          0
# ArmCircum                0
# SaggitalAbdominal        0
# GripStrength             0
# Total                    0
# Breast_fed               0
# medication               0
# Taking_Insulin           0
# Taking_Oral_Agents       0
# Eyes_Affected            0
# Recent_BP                0
# Diabetes                 0
# dtype: int64

# %%
datal.drop(['Family_income'],axis=1)
datal=datal[datal.columns]

# %%
datat.drop(['Family_income'],axis=1)
datat=datat[datat.columns]

# %%
import seaborn as sns
sns.pairplot(datak)

# %%
sns.pairplot(datal)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6735: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6736: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0dd34d8115e1> in <module>
# ----> 1 sns.pairplot(datal)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
#    2109             diag_kws.setdefault("shade", True)
#
# ...
